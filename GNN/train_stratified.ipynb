# %%
import torch 
import torch_geometric
from torch_geometric.loader import DataLoader
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, max_error
from scipy.stats import pearsonr
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import pandas as pd 
from tqdm import tqdm
from dataset import *
from model import *
from sklearn.model_selection import StratifiedKFold, KFold
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from math import sqrt
import warnings
warnings.filterwarnings("ignore")
device = torch.device("cpu")

# %%
torch_geometric.seed_everything(23)

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
carbides = MoC_c_dir(root = '/Users/ed/Documents/PhD_Documents/Experiments/Metal_carbides/Experiments_periodicity/NewData/Data')
'''print("Dataset type: ", type(data))
print("Dataset node features: ", data.num_features)
print("Dataset target: ", data.num_classes)
print("Dataset length: ", data.len)
print("Dataset sample: ", data[0])
print("Sample  nodes: ", data[0].num_nodes)
print("Sample  edges: ", data[0].num_edges)'''
# Out:
# 'print("Dataset type: ", type(data))\nprint("Dataset node features: ", data.num_features)\nprint("Dataset target: ", data.num_classes)\nprint("Dataset length: ", data.len)\nprint("Dataset sample: ", data[0])\nprint("Sample  nodes: ", data[0].num_nodes)\nprint("Sample  edges: ", data[0].num_edges)'

# %%
rm = []
for i in range(len(carbides)-1):
    if carbides[i].y < 1.5:
        rm.append(i)
rm
# Out:
# [306, 456, 508, 885]

# %%
indices_to_keep = [i for i in range(len(carbides)) if i not in rm]
data = carbides[indices_to_keep]

# %%
plt.plot(figsize =(12, 8))
plt.hist([torch.squeeze(data[i].y) for i in range(len(data))], bins = 7, color = 'blue', edgecolor='white')
plt.xlabel('Energy values', fontweight ='bold', fontsize = 12)
plt.ylabel('Frequency', fontweight ='bold', fontsize = 12)
plt.show()

# %%
x = [data[i].x.numpy() for i in range(data.len()-len(rm))]
x = np.array(x)
y = [data[i].y.numpy() for i in range(data.len()-len(rm))]
y = np.array(y)

# %%
#folds = StratifiedKFold(n_splits=5, shuffle=True)
folds = KFold(n_splits=5, shuffle=True)
train_idx = []
test_idx = []

for i, (train, test) in enumerate(folds.split(x, y)):
    train_idx.append(train)
    test_idx.append(test)

# %%
model = GCN_loop(data.num_features, embedding_size = 64, gnn_layers = 3, improved=False)
#model = GAT_original(data.num_features, embedding_size = 32, heads = 2)
print(model)
print(model.forward)
print("Number of parameters: ", count_parameters(model))
# Out:
# GCN_loop(
#   (initial_conv): GCNConv(5, 64)
#   (conv_layers): ModuleList(
#     (0-1): 2 x GCNConv(64, 64)
#   )
#   (out): Linear(in_features=128, out_features=1, bias=True)
# )
# <bound method GCN_loop.forward of GCN_loop(
#   (initial_conv): GCNConv(5, 64)
#   (conv_layers): ModuleList(
#     (0-1): 2 x GCNConv(64, 64)
#   )
#   (out): Linear(in_features=128, out_features=1, bias=True)
# )>
# Number of parameters:  8833

# %%
loss_fn = torch.nn.MSELoss()
optimiser = torch.optim.Adam(model.parameters(), lr = 0.01)
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer=optimiser, gamma = 0.995)

# %%
kfold_idx = 0

# %%
train_loader = DataLoader(data[train_idx[kfold_idx]], batch_size = 20, shuffle = True) 
test_loader = DataLoader(data[test_idx[kfold_idx]], batch_size = 10, shuffle = False)

# %%
train_y = [data[train_idx[kfold_idx]][i].y for i in range(len(data[train_idx[kfold_idx]]))]
test_y = [data[test_idx[kfold_idx]][i].y for i in range(len(data[test_idx[kfold_idx]]))]

print(f'The minimum training value is: {min(train_y)}, and the maximum is {max(train_y)}')
print(f'The minimum test value is: {min(test_y)}, and the maximum is {max(test_y)}')
# Out:
# The minimum training value is: tensor([1.9593], dtype=torch.float64), and the maximum is tensor([5.1743], dtype=torch.float64)
# The minimum test value is: tensor([2.1172], dtype=torch.float64), and the maximum is tensor([4.8013], dtype=torch.float64)

# %%
plt.plot(figsize = (12,8))
plt.hist(y[train_idx[kfold_idx]], 7, color = 'blue', label='Train set', edgecolor='white')
plt.hist(y[test_idx[kfold_idx]], 7, color = 'darkorange', label='Test set', edgecolor='black')
plt.xlabel('Energy values', fontweight ='bold', fontsize = 12)
plt.ylabel('Frequency', fontweight ='bold', fontsize = 12)
plt.legend()
plt.show()

# %%
def train(epoch):

    all_preds = []
    all_y = []
    total_loss = 0
    step = 0

    for batch in train_loader:

        # Use GPU
        batch.to(device)

        # Reset gradients
        optimiser.zero_grad()

        # Passing the node features and the connection info
        pred = model(batch.x.float(),  
                        batch.edge_index,
                        batch.batch)
        
        # Calculating the loss and gradients
        loss = torch.sqrt(loss_fn(pred, torch.unsqueeze(batch.y.float(), dim = 1)))
        loss.backward()

        # Update using the gradients
        optimiser.step() 

        total_loss += loss.item()
        step += 1

        all_preds.append(pred.cpu().detach().numpy())
        all_y.append(batch.y.cpu().detach().numpy())
    
    all_preds = np.concatenate(all_preds).ravel()
    all_labels = np.concatenate (all_y).ravel() 


    return torch.tensor(total_loss/step), all_preds, all_labels

# %%
def test (epoch):
    
    all_preds = []
    all_labels = []
    total_loss = 0
    step = 0

    for batch in test_loader:

        batch.to(device)
        pred = model(batch.x.float(),  
                        batch.edge_index, 
                        batch.batch)
        
        loss = torch.sqrt(loss_fn(pred, torch.unsqueeze(batch.y.float(), dim = 1)))

        total_loss += loss.item()
        step += 1

        all_preds.append(pred.cpu().detach().numpy())
        all_labels.append(batch.y.cpu().detach().numpy())

    all_preds = np.concatenate(all_preds).ravel()
    all_labels = np.concatenate(all_labels).ravel()

    return torch.tensor(total_loss/step), all_preds, all_labels

# %%
loss_train = []
loss_test = []

pred_train = []
pred_test = []

labels_train = []
labels_test = []

epochs = 501

for epoch in range (epochs):
            # Training
            model.train()
            loss, pred, label = train(epoch=epoch)
            loss = loss.detach().cpu().numpy()

            if epoch % 5 == 0:
                loss_train.append(loss) 

            if epoch % 100 == 0:
                   print(f"Epoch {epoch} | Train Loss {loss}")
                   pred_train.append(pred)
                   labels_train.append(label)

            # Testing
            model.eval()
            if epoch % 5 == 0:
                loss, pred, label = test(epoch=epoch)
                loss = loss.detach().cpu().numpy() 

                if epoch % 10 == 0:
                    loss_test.append(loss)

                if epoch % 100 == 0:
                    print(f"Epoch {epoch} | Test Loss {loss}")
                    pred_test.append(pred)
                    labels_test.append(label)

            scheduler.step()
# Out:
# Epoch 0 | Train Loss 0.6472018957138062
# Epoch 0 | Test Loss 0.5403504371643066
# Epoch 100 | Train Loss 0.5237478017807007
# Epoch 100 | Test Loss 0.541589081287384
# Epoch 200 | Train Loss 0.5279654264450073
# Epoch 200 | Test Loss 0.5354979038238525
# Epoch 300 | Train Loss 0.3035159409046173
# Epoch 300 | Test Loss 0.3198212683200836
# Epoch 400 | Train Loss 0.2273111492395401
# Epoch 400 | Test Loss 0.2628170847892761
# Epoch 500 | Train Loss 0.19327132403850555
# Epoch 500 | Test Loss 0.24776451289653778

# %%
n=2
plt.plot(range(0,epochs,5)[n:], loss_train[n:], 'o-', label = 'Train', color = 'blue')
plt.plot(range(0,epochs,10)[n:], loss_test[n:], 'o-', label = 'Test', color = 'darkorange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
e = 5

plt.scatter(labels_train[e], pred_train[e], color = 'blue', label = 'Train')
plt.scatter(labels_test[e], pred_test[e], color = 'darkorange', label = 'Test')
plt.xlabel("Calculated Energy (DFT) / eV")
plt.ylabel("Predicted Energy / eV")
plt.legend()

plt.text(2.1, 3.5, f'R2: {pearsonr(labels_train[e], pred_train[e])[0]**2:.2f} \n\
MAE: {mean_absolute_error(labels_train[e], pred_train[e]):.2f} \n\
RMSE: {sqrt(mean_squared_error(labels_train[e], pred_train[e])):.2f}', color = 'b')

plt.text(4.25, 2.9, f'R2:  {pearsonr(labels_test[e], pred_test[e])[0]**2:.2f}\n\
MAE: {mean_absolute_error(labels_test[e], pred_test[e]):.2f} \n\
RMSE: {sqrt(mean_squared_error(labels_test[e], pred_test[e])):.2f}', color = 'darkorange')
plt.show()

# %%
def train_folds(kfold, epoch, model, optimiser, loader):

    all_preds = []
    all_y = []
    all_file = []
    total_loss = 0
    step = 0

    for batch in loader:

        # Use GPU
        batch.to(device)
        

        # Reset gradients
        optimiser.zero_grad()

        # Passing the node features and the connection info
        pred = model(batch.x.float(),  
                        batch.edge_index,
                        batch.batch)
        
        
        # Calculating the loss and gradients
        loss = torch.sqrt(loss_fn(pred, torch.unsqueeze(batch.y.float(), dim = 1)))

        loss.backward()

        # Update using the gradients
        optimiser.step() 

        total_loss += loss.item()
        step += 1
        

        all_preds.append(pred.cpu().detach().numpy())
        all_y.append(batch.y.cpu().detach().numpy())
        all_file.append(batch.file_name)
    
    all_preds = np.concatenate(all_preds).ravel()
    all_labels = np.concatenate (all_y).ravel() 
    all_file = np.concatenate(all_file).ravel()
    
    return torch.tensor(total_loss/step), all_preds, all_labels, all_file

# %%
def test_folds(kfold, epoch, model, loader):
    
    all_preds = []
    all_labels = []
    all_file = []
    total_loss = 0
    step = 0

    for batch in loader:

        batch.to(device)
        pred = model(batch.x.float(),  
                        batch.edge_index, 
                        batch.batch)
        
        loss = torch.sqrt(loss_fn(pred, torch.unsqueeze(batch.y.float(), dim = 1)))

        total_loss += loss.item()
        step += 1

        all_preds.append(pred.cpu().detach().numpy())
        all_labels.append(batch.y.cpu().detach().numpy())
        all_file.append(batch.file_name)

    all_preds = np.concatenate(all_preds).ravel()
    all_labels = np.concatenate(all_labels).ravel()
    all_file = np.concatenate(all_file).ravel()

    return torch.tensor(total_loss/step), all_preds, all_labels, all_file

# %%
epochs = 1201

#folds x times loss is saved
loss_train_folds = np.zeros((len(train_idx), len(range(0, epochs,  5))))
loss_test_folds = np.zeros((len(train_idx), len(range(0, epochs,  5))))

#times preds are saved x number of predictions x folds
pred_train_folds = [np.zeros((len(train_idx[i]), len(range(0, epochs, 5)))) for i in range(len(train_idx))] 
pred_test_folds = [np.zeros((len(test_idx[i]), len(range(0, epochs, 5)))) for i in range(len(train_idx))]

#times lables are saved x number of predictions x folds
labels_train_folds = [np.zeros((len(train_idx[i]), len(range(0, epochs, 5)))) for i in range(len(train_idx))] 
labels_test_folds = [np.zeros((len(test_idx[i]), len(range(0, epochs, 5)))) for i in range(len(train_idx))]

#times file are saved x number of predictions x folds
file_train_folds = [[[None] * len(train_idx[i])] * len(range(0, epochs, 5)) for i in range(len(train_idx))] 
file_test_folds = [[[None] * len(test_idx[i])] * len(range(0, epochs, 5)) for i in range(len(train_idx))]

# %%
for fold in range(len(train_idx)):

    model = GCN_loop(data.num_features, embedding_size = 64, gnn_layers = 3, improved=False)
    loss_fn = torch.nn.MSELoss()
    optimiser = torch.optim.Adam(model.parameters(), lr = 0.01)
    scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer=optimiser, gamma = 0.995)
    train_loader = DataLoader(data[train_idx[fold]], batch_size = 20, shuffle = True) 
    test_loader = DataLoader(data[test_idx[fold]], batch_size = 10, shuffle = False) 


    for epoch in range (epochs):

        # Training
        model.train()
        loss, pred, label, file = train_folds(kfold = fold, 
                                        epoch=epoch, 
                                        model = model, 
                                        optimiser = optimiser, 
                                        loader = train_loader)
        
        
        loss = loss.detach().cpu().numpy()

        if epoch % 5 == 0:
            loss_train_folds[fold, int(epoch / 5)] = loss

        if epoch % 5 == 0:
            print(f"Epoch {epoch} | Fold {fold} | Train Loss {loss}")
            pred_train_folds[fold][:, int(epoch/5)] = pred
            labels_train_folds[fold][:, int(epoch/5)] = label
            file_train_folds[fold][int(epoch/5)] = file


        # Testing
        model.eval()

        if epoch % 5 == 0:
            loss, pred, label, file = test_folds(kfold = fold, 
                                           epoch=epoch, 
                                           model=model,
                                           loader = test_loader)
            loss = loss.detach().cpu().numpy() 

            if epoch % 5 == 0:
                loss_test_folds[fold, int(epoch / 5)] = loss

            if epoch % 5 == 0:
                print(f"Epoch {epoch} | Fold {fold} | Test Loss {loss}")
                pred_test_folds[fold][:, int(epoch/5)] = pred
                labels_test_folds[fold][:, int(epoch/5)] = label
                file_test_folds[fold][int(epoch/5)] = file
        
        scheduler.step()
    
    print(f'Done for fold {fold}')
# Out:
# Epoch 0 | Fold 0 | Train Loss 0.6958028674125671
# Epoch 0 | Fold 0 | Test Loss 0.5099427103996277
# Epoch 5 | Fold 0 | Train Loss 0.536719024181366
# Epoch 5 | Fold 0 | Test Loss 0.6954469680786133
# Epoch 10 | Fold 0 | Train Loss 0.5323464274406433
# Epoch 10 | Fold 0 | Test Loss 0.5190691947937012
# Epoch 15 | Fold 0 | Train Loss 0.554284930229187
# Epoch 15 | Fold 0 | Test Loss 0.5153992772102356
# Epoch 20 | Fold 0 | Train Loss 0.5521737337112427
# Epoch 20 | Fold 0 | Test Loss 0.5433194637298584
# Epoch 25 | Fold 0 | Train Loss 0.5459868907928467
# Epoch 25 | Fold 0 | Test Loss 0.5047494769096375
# Epoch 30 | Fold 0 | Train Loss 0.5482044219970703
# Epoch 30 | Fold 0 | Test Loss 0.5192384719848633
# Epoch 35 | Fold 0 | Train Loss 0.5443093776702881
# Epoch 35 | Fold 0 | Test Loss 0.512078046798706
# Epoch 40 | Fold 0 | Train Loss 0.5665608644485474
# Epoch 40 | Fold 0 | Test Loss 0.5370649695396423
# Epoch 45 | Fold 0 | Train Loss 0.5376172065734863
# Epoch 45 | Fold 0 | Test Loss 0.5407238006591797
# Epoch 50 | Fold 0 | Train Loss 0.5245870351791382
# Epoch 50 | Fold 0 | Test Loss 0.5078334212303162
# Epoch 55 | Fold 0 | Train Loss 0.5351980924606323
# Epoch 55 | Fold 0 | Test Loss 0.5100358128547668
# Epoch 60 | Fold 0 | Train Loss 0.5572348833084106
# Epoch 60 | Fold 0 | Test Loss 0.5248804688453674
# Epoch 65 | Fold 0 | Train Loss 0.5393173694610596
# Epoch 65 | Fold 0 | Test Loss 0.5352098941802979
# Epoch 70 | Fold 0 | Train Loss 0.5335256457328796
# Epoch 70 | Fold 0 | Test Loss 0.5232228636741638
# Epoch 75 | Fold 0 | Train Loss 0.5249356031417847
# Epoch 75 | Fold 0 | Test Loss 0.5128223896026611
# Epoch 80 | Fold 0 | Train Loss 0.566959798336029
# Epoch 80 | Fold 0 | Test Loss 0.5059856176376343
# Epoch 85 | Fold 0 | Train Loss 0.5333787798881531
# Epoch 85 | Fold 0 | Test Loss 0.5361694097518921
# Epoch 90 | Fold 0 | Train Loss 0.5584618449211121
# Epoch 90 | Fold 0 | Test Loss 0.5208856463432312
# Epoch 95 | Fold 0 | Train Loss 0.533636212348938
# Epoch 95 | Fold 0 | Test Loss 0.5128268599510193
# Epoch 100 | Fold 0 | Train Loss 0.5366336107254028
# Epoch 100 | Fold 0 | Test Loss 0.537549614906311
# Epoch 105 | Fold 0 | Train Loss 0.5249345302581787
# Epoch 105 | Fold 0 | Test Loss 0.5107752680778503
# Epoch 110 | Fold 0 | Train Loss 0.52813720703125
# Epoch 110 | Fold 0 | Test Loss 0.5051623582839966
# Epoch 115 | Fold 0 | Train Loss 0.5406166315078735
# Epoch 115 | Fold 0 | Test Loss 0.5129354000091553
# Epoch 120 | Fold 0 | Train Loss 0.5491945147514343
# Epoch 120 | Fold 0 | Test Loss 0.5728148221969604
# Epoch 125 | Fold 0 | Train Loss 0.5476430058479309
# Epoch 125 | Fold 0 | Test Loss 0.5071517825126648
# Epoch 130 | Fold 0 | Train Loss 0.5371723175048828
# Epoch 130 | Fold 0 | Test Loss 0.513307511806488
# Epoch 135 | Fold 0 | Train Loss 0.5271607637405396
# Epoch 135 | Fold 0 | Test Loss 0.5099992752075195
# Epoch 140 | Fold 0 | Train Loss 0.5338347554206848
# Epoch 140 | Fold 0 | Test Loss 0.5766454935073853
# Epoch 145 | Fold 0 | Train Loss 0.5236296057701111
# Epoch 145 | Fold 0 | Test Loss 0.5134137868881226
# Epoch 150 | Fold 0 | Train Loss 0.5305442810058594
# Epoch 150 | Fold 0 | Test Loss 0.5167126059532166
# Epoch 155 | Fold 0 | Train Loss 0.5260663628578186
# Epoch 155 | Fold 0 | Test Loss 0.5009638071060181
# Epoch 160 | Fold 0 | Train Loss 0.5235061645507812
# Epoch 160 | Fold 0 | Test Loss 0.5052891373634338
# Epoch 165 | Fold 0 | Train Loss 0.5472111105918884
# Epoch 165 | Fold 0 | Test Loss 0.556889533996582
# Epoch 170 | Fold 0 | Train Loss 0.5241780877113342
# Epoch 170 | Fold 0 | Test Loss 0.5095990300178528
# Epoch 175 | Fold 0 | Train Loss 0.5232071876525879
# Epoch 175 | Fold 0 | Test Loss 0.5417256355285645
# Epoch 180 | Fold 0 | Train Loss 0.534483790397644
# Epoch 180 | Fold 0 | Test Loss 0.5428088307380676
# Epoch 185 | Fold 0 | Train Loss 0.5309723615646362
# Epoch 185 | Fold 0 | Test Loss 0.5322690606117249
# Epoch 190 | Fold 0 | Train Loss 0.5619179606437683
# Epoch 190 | Fold 0 | Test Loss 0.519760251045227
# Epoch 195 | Fold 0 | Train Loss 0.5342197418212891
# Epoch 195 | Fold 0 | Test Loss 0.5059322714805603
# Epoch 200 | Fold 0 | Train Loss 0.5222903490066528
# Epoch 200 | Fold 0 | Test Loss 0.5196388363838196
# Epoch 205 | Fold 0 | Train Loss 0.5400305390357971
# Epoch 205 | Fold 0 | Test Loss 0.5297756791114807
# Epoch 210 | Fold 0 | Train Loss 0.5329627394676208
# Epoch 210 | Fold 0 | Test Loss 0.5317678451538086
# Epoch 215 | Fold 0 | Train Loss 0.5267956256866455
# Epoch 215 | Fold 0 | Test Loss 0.5169271230697632
# Epoch 220 | Fold 0 | Train Loss 0.5234245657920837
# Epoch 220 | Fold 0 | Test Loss 0.507827877998352
# Epoch 225 | Fold 0 | Train Loss 0.5269402861595154
# Epoch 225 | Fold 0 | Test Loss 0.5054612159729004
# Epoch 230 | Fold 0 | Train Loss 0.5399259924888611
# Epoch 230 | Fold 0 | Test Loss 0.521295428276062
# Epoch 235 | Fold 0 | Train Loss 0.5229928493499756
# Epoch 235 | Fold 0 | Test Loss 0.5057519674301147
# Epoch 240 | Fold 0 | Train Loss 0.5223313570022583
# Epoch 240 | Fold 0 | Test Loss 0.5919591188430786
# Epoch 245 | Fold 0 | Train Loss 0.5343780517578125
# Epoch 245 | Fold 0 | Test Loss 0.509879469871521
# Epoch 250 | Fold 0 | Train Loss 0.5350509285926819
# Epoch 250 | Fold 0 | Test Loss 0.5102660059928894
# Epoch 255 | Fold 0 | Train Loss 0.5285018682479858
# Epoch 255 | Fold 0 | Test Loss 0.5520370006561279
# Epoch 260 | Fold 0 | Train Loss 0.5380236506462097
# Epoch 260 | Fold 0 | Test Loss 0.5666691660881042
# Epoch 265 | Fold 0 | Train Loss 0.5311331748962402
# Epoch 265 | Fold 0 | Test Loss 0.5294914841651917
# Epoch 270 | Fold 0 | Train Loss 0.524293839931488
# Epoch 270 | Fold 0 | Test Loss 0.5047250390052795
# Epoch 275 | Fold 0 | Train Loss 0.523592472076416
# Epoch 275 | Fold 0 | Test Loss 0.5134409666061401
# Epoch 280 | Fold 0 | Train Loss 0.5302276611328125
# Epoch 280 | Fold 0 | Test Loss 0.5256366729736328
# Epoch 285 | Fold 0 | Train Loss 0.5295223593711853
# Epoch 285 | Fold 0 | Test Loss 0.5346850752830505
# Epoch 290 | Fold 0 | Train Loss 0.5253357887268066
# Epoch 290 | Fold 0 | Test Loss 0.5064558982849121
# Epoch 295 | Fold 0 | Train Loss 0.5246878266334534
# Epoch 295 | Fold 0 | Test Loss 0.5068886280059814
# Epoch 300 | Fold 0 | Train Loss 0.5256727933883667
# Epoch 300 | Fold 0 | Test Loss 0.5244372487068176
# Epoch 305 | Fold 0 | Train Loss 0.5298326015472412
# Epoch 305 | Fold 0 | Test Loss 0.5041817426681519
# Epoch 310 | Fold 0 | Train Loss 0.5244352221488953
# Epoch 310 | Fold 0 | Test Loss 0.541779637336731
# Epoch 315 | Fold 0 | Train Loss 0.5240045785903931
# Epoch 315 | Fold 0 | Test Loss 0.5102927088737488
# Epoch 320 | Fold 0 | Train Loss 0.5206686854362488
# Epoch 320 | Fold 0 | Test Loss 0.5121380090713501
# Epoch 325 | Fold 0 | Train Loss 0.5091213583946228
# Epoch 325 | Fold 0 | Test Loss 0.504037082195282
# Epoch 330 | Fold 0 | Train Loss 0.47460705041885376
# Epoch 330 | Fold 0 | Test Loss 0.4962327182292938
# Epoch 335 | Fold 0 | Train Loss 0.40169066190719604
# Epoch 335 | Fold 0 | Test Loss 0.3916967511177063
# Epoch 340 | Fold 0 | Train Loss 0.39570820331573486
# Epoch 340 | Fold 0 | Test Loss 0.41019484400749207
# Epoch 345 | Fold 0 | Train Loss 0.3889603018760681
# Epoch 345 | Fold 0 | Test Loss 0.4031810462474823
# Epoch 350 | Fold 0 | Train Loss 0.3926098942756653
# Epoch 350 | Fold 0 | Test Loss 0.38113099336624146
# Epoch 355 | Fold 0 | Train Loss 0.3685409426689148
# Epoch 355 | Fold 0 | Test Loss 0.4021437466144562
# Epoch 360 | Fold 0 | Train Loss 0.3712405562400818
# Epoch 360 | Fold 0 | Test Loss 0.3713827431201935
# Epoch 365 | Fold 0 | Train Loss 0.3657553791999817
# Epoch 365 | Fold 0 | Test Loss 0.3671638071537018
# Epoch 370 | Fold 0 | Train Loss 0.3579578995704651
# Epoch 370 | Fold 0 | Test Loss 0.36482930183410645
# Epoch 375 | Fold 0 | Train Loss 0.35218411684036255
# Epoch 375 | Fold 0 | Test Loss 0.3506506383419037
# Epoch 380 | Fold 0 | Train Loss 0.33248838782310486
# Epoch 380 | Fold 0 | Test Loss 0.34753403067588806
# Epoch 385 | Fold 0 | Train Loss 0.3249947726726532
# Epoch 385 | Fold 0 | Test Loss 0.3364989757537842
# Epoch 390 | Fold 0 | Train Loss 0.32793983817100525
# Epoch 390 | Fold 0 | Test Loss 0.3263671100139618
# Epoch 395 | Fold 0 | Train Loss 0.32310932874679565
# Epoch 895 | Fold 0 | Train Loss 0.18479710817337036
# Epoch 895 | Fold 0 | Test Loss 0.22329875826835632
# Epoch 900 | Fold 0 | Train Loss 0.18379108607769012
# Epoch 900 | Fold 0 | Test Loss 0.22455944120883942
# Epoch 905 | Fold 0 | Train Loss 0.18071222305297852
# Epoch 905 | Fold 0 | Test Loss 0.22510404884815216
# Epoch 910 | Fold 0 | Train Loss 0.18286940455436707
# Epoch 910 | Fold 0 | Test Loss 0.2258080095052719
# Epoch 915 | Fold 0 | Train Loss 0.18270014226436615
# Epoch 915 | Fold 0 | Test Loss 0.22699092328548431
# Epoch 920 | Fold 0 | Train Loss 0.18070615828037262
# Epoch 920 | Fold 0 | Test Loss 0.2297387421131134
# Epoch 925 | Fold 0 | Train Loss 0.1835532933473587
# Epoch 925 | Fold 0 | Test Loss 0.2258010059595108
# Epoch 930 | Fold 0 | Train Loss 0.1813199669122696
# Epoch 930 | Fold 0 | Test Loss 0.22378534078598022
# Epoch 935 | Fold 0 | Train Loss 0.1815294474363327
# Epoch 935 | Fold 0 | Test Loss 0.22271640598773956
# Epoch 940 | Fold 0 | Train Loss 0.18064990639686584
# Epoch 940 | Fold 0 | Test Loss 0.22278685867786407
# Epoch 945 | Fold 0 | Train Loss 0.18047764897346497
# Epoch 945 | Fold 0 | Test Loss 0.23682264983654022
# Epoch 950 | Fold 0 | Train Loss 0.18073834478855133
# Epoch 950 | Fold 0 | Test Loss 0.22257977724075317
# Epoch 955 | Fold 0 | Train Loss 0.18075881898403168
# Epoch 955 | Fold 0 | Test Loss 0.22346603870391846
# Epoch 960 | Fold 0 | Train Loss 0.1820618361234665
# Epoch 960 | Fold 0 | Test Loss 0.22653035819530487
# Epoch 965 | Fold 0 | Train Loss 0.17952728271484375
# Epoch 965 | Fold 0 | Test Loss 0.22271960973739624
# Epoch 970 | Fold 0 | Train Loss 0.18091176450252533
# Epoch 970 | Fold 0 | Test Loss 0.22239483892917633
# Epoch 975 | Fold 0 | Train Loss 0.178231343626976
# Epoch 975 | Fold 0 | Test Loss 0.22452223300933838
# Epoch 980 | Fold 0 | Train Loss 0.1796528846025467
# Epoch 980 | Fold 0 | Test Loss 0.2225751429796219
# Epoch 985 | Fold 0 | Train Loss 0.1818690299987793
# Epoch 985 | Fold 0 | Test Loss 0.22262665629386902
# Epoch 990 | Fold 0 | Train Loss 0.18044476211071014
# Epoch 990 | Fold 0 | Test Loss 0.22273221611976624
# Epoch 995 | Fold 0 | Train Loss 0.1769692748785019
# Epoch 995 | Fold 0 | Test Loss 0.224399134516716
# Epoch 1000 | Fold 0 | Train Loss 0.18093034625053406
# Epoch 1000 | Fold 0 | Test Loss 0.22161976993083954
# Epoch 1005 | Fold 0 | Train Loss 0.17865046858787537
# Epoch 1005 | Fold 0 | Test Loss 0.223222017288208
# Epoch 1010 | Fold 0 | Train Loss 0.17686349153518677
# Epoch 1010 | Fold 0 | Test Loss 0.22220319509506226
# Epoch 1015 | Fold 0 | Train Loss 0.17872729897499084
# Epoch 1015 | Fold 0 | Test Loss 0.22657161951065063
# Epoch 55 | Fold 1 | Test Loss 0.5438082814216614
# Epoch 60 | Fold 1 | Train Loss 0.5453900098800659
# Epoch 60 | Fold 1 | Test Loss 0.5218310356140137
# Epoch 65 | Fold 1 | Train Loss 0.554614245891571
# Epoch 65 | Fold 1 | Test Loss 0.6608467698097229
# Epoch 70 | Fold 1 | Train Loss 0.5695838332176208
# Epoch 70 | Fold 1 | Test Loss 0.5865552425384521
# Epoch 75 | Fold 1 | Train Loss 0.543545663356781
# Epoch 75 | Fold 1 | Test Loss 0.5208543539047241
# Epoch 80 | Fold 1 | Train Loss 0.5236794352531433
# Epoch 80 | Fold 1 | Test Loss 0.5663341283798218
# Epoch 85 | Fold 1 | Train Loss 0.5267875790596008
# Epoch 85 | Fold 1 | Test Loss 0.5944157838821411
# Epoch 90 | Fold 1 | Train Loss 0.5249419212341309
# Epoch 90 | Fold 1 | Test Loss 0.526909589767456
# Epoch 95 | Fold 1 | Train Loss 0.5492062568664551
# Epoch 95 | Fold 1 | Test Loss 0.5233410596847534
# Epoch 100 | Fold 1 | Train Loss 0.5170568227767944
# Epoch 100 | Fold 1 | Test Loss 0.5055060982704163
# Epoch 105 | Fold 1 | Train Loss 0.5453585982322693
# Epoch 105 | Fold 1 | Test Loss 0.5218542814254761
# Epoch 110 | Fold 1 | Train Loss 0.538553774356842
# Epoch 110 | Fold 1 | Test Loss 0.5340385437011719
# Epoch 115 | Fold 1 | Train Loss 0.5320901870727539
# Epoch 115 | Fold 1 | Test Loss 0.5319160223007202
# Epoch 120 | Fold 1 | Train Loss 0.5284419655799866
# Epoch 120 | Fold 1 | Test Loss 0.5530571937561035
# Epoch 125 | Fold 1 | Train Loss 0.54281085729599
# Epoch 125 | Fold 1 | Test Loss 0.560291051864624
# Epoch 130 | Fold 1 | Train Loss 0.5199213027954102
# Epoch 130 | Fold 1 | Test Loss 0.5263767838478088
# Epoch 135 | Fold 1 | Train Loss 0.5321502685546875
# Epoch 135 | Fold 1 | Test Loss 0.5530620217323303
# Epoch 140 | Fold 1 | Train Loss 0.5250052213668823
# Epoch 140 | Fold 1 | Test Loss 0.5232135653495789
# Epoch 145 | Fold 1 | Train Loss 0.5175952315330505
# Epoch 145 | Fold 1 | Test Loss 0.567774772644043
# Epoch 150 | Fold 1 | Train Loss 0.5265247225761414
# Epoch 150 | Fold 1 | Test Loss 0.5305477380752563
# Epoch 155 | Fold 1 | Train Loss 0.5536015033721924
# Epoch 155 | Fold 1 | Test Loss 0.5509994029998779
# Epoch 160 | Fold 1 | Train Loss 0.5137441754341125
# Epoch 160 | Fold 1 | Test Loss 0.5330784916877747
# Epoch 165 | Fold 1 | Train Loss 0.5192912817001343
# Epoch 165 | Fold 1 | Test Loss 0.5306960344314575
# Epoch 170 | Fold 1 | Train Loss 0.557733416557312
# Epoch 170 | Fold 1 | Test Loss 0.6029869914054871
# Epoch 175 | Fold 1 | Train Loss 0.5489411950111389
# Epoch 175 | Fold 1 | Test Loss 0.5348077416419983
# Epoch 180 | Fold 1 | Train Loss 0.5178576111793518
# Epoch 575 | Fold 4 | Test Loss 0.247853085398674
# Epoch 580 | Fold 4 | Train Loss 0.2329225093126297
# Epoch 580 | Fold 4 | Test Loss 0.2705173194408417
# Epoch 585 | Fold 4 | Train Loss 0.2461691051721573
# Epoch 585 | Fold 4 | Test Loss 0.2740648686885834
# Epoch 590 | Fold 4 | Train Loss 0.23408080637454987
# Epoch 590 | Fold 4 | Test Loss 0.2696956694126129
# Epoch 595 | Fold 4 | Train Loss 0.23442625999450684
# Epoch 595 | Fold 4 | Test Loss 0.24903586506843567
# Epoch 600 | Fold 4 | Train Loss 0.2298019379377365
# Epoch 600 | Fold 4 | Test Loss 0.2734159529209137
# Epoch 605 | Fold 4 | Train Loss 0.23095785081386566
# Epoch 605 | Fold 4 | Test Loss 0.25523287057876587
# Epoch 610 | Fold 4 | Train Loss 0.2267296463251114
# Epoch 610 | Fold 4 | Test Loss 0.2667153775691986
# Epoch 615 | Fold 4 | Train Loss 0.22877024114131927
# Epoch 615 | Fold 4 | Test Loss 0.2534874975681305
# Epoch 620 | Fold 4 | Train Loss 0.22786539793014526
# Epoch 620 | Fold 4 | Test Loss 0.24760764837265015
# Epoch 625 | Fold 4 | Train Loss 0.22574205696582794
# Epoch 625 | Fold 4 | Test Loss 0.25903260707855225
# Epoch 630 | Fold 4 | Train Loss 0.22680498659610748
# Epoch 630 | Fold 4 | Test Loss 0.25721514225006104
# Epoch 635 | Fold 4 | Train Loss 0.22744517028331757
# Epoch 635 | Fold 4 | Test Loss 0.24803806841373444
# Epoch 640 | Fold 4 | Train Loss 0.23197175562381744
# Epoch 640 | Fold 4 | Test Loss 0.2512865364551544
# Epoch 645 | Fold 4 | Train Loss 0.22105135023593903
# Epoch 645 | Fold 4 | Test Loss 0.2494305819272995
# Epoch 650 | Fold 4 | Train Loss 0.2244996577501297
# Epoch 650 | Fold 4 | Test Loss 0.2501879334449768
# Epoch 655 | Fold 4 | Train Loss 0.22185158729553223
# Epoch 655 | Fold 4 | Test Loss 0.2523730397224426
# Epoch 660 | Fold 4 | Train Loss 0.218713641166687
# Epoch 660 | Fold 4 | Test Loss 0.2622229754924774
# Epoch 665 | Fold 4 | Train Loss 0.22635960578918457
# Epoch 665 | Fold 4 | Test Loss 0.24742092192173004
# Epoch 670 | Fold 4 | Train Loss 0.21437618136405945
# Epoch 670 | Fold 4 | Test Loss 0.25403347611427307
# Epoch 675 | Fold 4 | Train Loss 0.21379083395004272
# Epoch 675 | Fold 4 | Test Loss 0.2650049328804016
# Epoch 680 | Fold 4 | Train Loss 0.21519361436367035
# Epoch 680 | Fold 4 | Test Loss 0.2494259625673294
# Epoch 685 | Fold 4 | Train Loss 0.21523182094097137
# Epoch 685 | Fold 4 | Test Loss 0.24941900372505188
# Epoch 690 | Fold 4 | Train Loss 0.21203722059726715
# Epoch 690 | Fold 4 | Test Loss 0.2470659762620926
# Epoch 695 | Fold 4 | Train Loss 0.21348431706428528
# Epoch 695 | Fold 4 | Test Loss 0.25168663263320923
# Epoch 700 | Fold 4 | Train Loss 0.21407222747802734
# Epoch 700 | Fold 4 | Test Loss 0.24664683640003204
# Epoch 705 | Fold 4 | Train Loss 0.2103215903043747
# Epoch 705 | Fold 4 | Test Loss 0.2550153136253357
# Epoch 710 | Fold 4 | Train Loss 0.22127053141593933
# Epoch 710 | Fold 4 | Test Loss 0.2468075305223465
# Epoch 715 | Fold 4 | Train Loss 0.21009063720703125
# Epoch 715 | Fold 4 | Test Loss 0.24761007726192474
# Epoch 720 | Fold 4 | Train Loss 0.20963168144226074
# Epoch 720 | Fold 4 | Test Loss 0.26166602969169617
# Epoch 725 | Fold 4 | Train Loss 0.20652388036251068
# Epoch 725 | Fold 4 | Test Loss 0.24676936864852905
# Epoch 730 | Fold 4 | Train Loss 0.2078176587820053
# Epoch 730 | Fold 4 | Test Loss 0.2506016790866852
# Epoch 735 | Fold 4 | Train Loss 0.2065974920988083
# Epoch 735 | Fold 4 | Test Loss 0.2499076873064041
# Epoch 740 | Fold 4 | Train Loss 0.21123632788658142
# Epoch 740 | Fold 4 | Test Loss 0.2547331154346466
# Epoch 745 | Fold 4 | Train Loss 0.2062043398618698
# Epoch 745 | Fold 4 | Test Loss 0.24630092084407806
# Epoch 750 | Fold 4 | Train Loss 0.21256600320339203
# Epoch 750 | Fold 4 | Test Loss 0.2480737417936325
# Epoch 755 | Fold 4 | Train Loss 0.20312005281448364
# Epoch 755 | Fold 4 | Test Loss 0.25327494740486145
# Epoch 760 | Fold 4 | Train Loss 0.2052130252122879
# Epoch 760 | Fold 4 | Test Loss 0.2457069307565689
# Epoch 765 | Fold 4 | Train Loss 0.2026810348033905
# Epoch 765 | Fold 4 | Test Loss 0.24697747826576233
# Epoch 770 | Fold 4 | Train Loss 0.20335783064365387
# Epoch 770 | Fold 4 | Test Loss 0.25024059414863586
# Epoch 775 | Fold 4 | Train Loss 0.19994941353797913
# Epoch 775 | Fold 4 | Test Loss 0.25023624300956726
# Epoch 780 | Fold 4 | Train Loss 0.20301483571529388
# Epoch 780 | Fold 4 | Test Loss 0.24608485400676727
# Epoch 785 | Fold 4 | Train Loss 0.198277086019516
# Epoch 785 | Fold 4 | Test Loss 0.2606890797615051
# Epoch 790 | Fold 4 | Train Loss 0.19974303245544434
# Epoch 790 | Fold 4 | Test Loss 0.24547334015369415
# Epoch 795 | Fold 4 | Train Loss 0.1995498090982437
# Epoch 795 | Fold 4 | Test Loss 0.25330424308776855
# Epoch 800 | Fold 4 | Train Loss 0.19726459681987762
# Epoch 800 | Fold 4 | Test Loss 0.24962392449378967
# Epoch 805 | Fold 4 | Train Loss 0.19843542575836182
# Epoch 805 | Fold 4 | Test Loss 0.2524683475494385
# Epoch 810 | Fold 4 | Train Loss 0.1977555900812149
# Epoch 810 | Fold 4 | Test Loss 0.24829496443271637
# Epoch 815 | Fold 4 | Train Loss 0.19821049273014069
# Epoch 815 | Fold 4 | Test Loss 0.25034099817276
# Epoch 820 | Fold 4 | Train Loss 0.1960022747516632
# Epoch 820 | Fold 4 | Test Loss 0.2456355094909668
# Epoch 825 | Fold 4 | Train Loss 0.19882594048976898
# Epoch 825 | Fold 4 | Test Loss 0.24511894583702087
# Epoch 830 | Fold 4 | Train Loss 0.19784094393253326
# Epoch 830 | Fold 4 | Test Loss 0.2504035234451294
# Epoch 835 | Fold 4 | Train Loss 0.19401003420352936
# Epoch 835 | Fold 4 | Test Loss 0.24408739805221558
# Epoch 840 | Fold 4 | Train Loss 0.19418735802173615
# Epoch 840 | Fold 4 | Test Loss 0.2460733950138092
# Epoch 845 | Fold 4 | Train Loss 0.19369781017303467
# Epoch 845 | Fold 4 | Test Loss 0.24784907698631287
# Epoch 850 | Fold 4 | Train Loss 0.19230449199676514
# Epoch 850 | Fold 4 | Test Loss 0.24625341594219208
# Epoch 855 | Fold 4 | Train Loss 0.19182604551315308
# Epoch 855 | Fold 4 | Test Loss 0.24369658529758453
# Epoch 860 | Fold 4 | Train Loss 0.1916227489709854
# Epoch 860 | Fold 4 | Test Loss 0.24390017986297607
# Epoch 865 | Fold 4 | Train Loss 0.19211269915103912
# Epoch 865 | Fold 4 | Test Loss 0.24382296204566956
# Epoch 870 | Fold 4 | Train Loss 0.19119440019130707
# Epoch 870 | Fold 4 | Test Loss 0.24423396587371826
# Epoch 875 | Fold 4 | Train Loss 0.1906014382839203
# Epoch 875 | Fold 4 | Test Loss 0.2510029077529907
# Epoch 880 | Fold 4 | Train Loss 0.1879955381155014
# Epoch 880 | Fold 4 | Test Loss 0.24751494824886322
# Epoch 885 | Fold 4 | Train Loss 0.18950319290161133
# Epoch 885 | Fold 4 | Test Loss 0.2429247796535492
# Epoch 890 | Fold 4 | Train Loss 0.18913613259792328
# Epoch 890 | Fold 4 | Test Loss 0.24295425415039062
# Epoch 895 | Fold 4 | Train Loss 0.1900840401649475
# Epoch 895 | Fold 4 | Test Loss 0.2425343245267868
# Epoch 900 | Fold 4 | Train Loss 0.1911463439464569
# Epoch 900 | Fold 4 | Test Loss 0.24885158240795135
# Epoch 905 | Fold 4 | Train Loss 0.1877768337726593
# Epoch 905 | Fold 4 | Test Loss 0.24251583218574524
# Epoch 910 | Fold 4 | Train Loss 0.19075936079025269
# Epoch 910 | Fold 4 | Test Loss 0.24232330918312073
# Epoch 915 | Fold 4 | Train Loss 0.1852671355009079
# Epoch 915 | Fold 4 | Test Loss 0.24291521310806274
# Epoch 920 | Fold 4 | Train Loss 0.18622379004955292
# Epoch 920 | Fold 4 | Test Loss 0.24212580919265747
# Epoch 925 | Fold 4 | Train Loss 0.18802496790885925
# Epoch 925 | Fold 4 | Test Loss 0.24253180623054504
# Epoch 930 | Fold 4 | Train Loss 0.1876859813928604
# Epoch 930 | Fold 4 | Test Loss 0.24143756926059723
# Epoch 935 | Fold 4 | Train Loss 0.1852378100156784
# Epoch 935 | Fold 4 | Test Loss 0.24195311963558197
# Epoch 940 | Fold 4 | Train Loss 0.1859624683856964
# Epoch 940 | Fold 4 | Test Loss 0.24822157621383667
# Epoch 945 | Fold 4 | Train Loss 0.18498995900154114
# Epoch 945 | Fold 4 | Test Loss 0.24200323224067688
# Epoch 950 | Fold 4 | Train Loss 0.18342144787311554
# Epoch 950 | Fold 4 | Test Loss 0.24153591692447662
# Epoch 955 | Fold 4 | Train Loss 0.18516391515731812
# Epoch 955 | Fold 4 | Test Loss 0.2429802119731903
# Epoch 960 | Fold 4 | Train Loss 0.18521976470947266
# Epoch 960 | Fold 4 | Test Loss 0.24259446561336517
# Epoch 965 | Fold 4 | Train Loss 0.18352153897285461
# Epoch 965 | Fold 4 | Test Loss 0.2513892948627472
# Epoch 970 | Fold 4 | Train Loss 0.18306374549865723
# Epoch 970 | Fold 4 | Test Loss 0.24729163944721222
# Epoch 975 | Fold 4 | Train Loss 0.18395856022834778
# Epoch 975 | Fold 4 | Test Loss 0.2414858639240265
# Epoch 980 | Fold 4 | Train Loss 0.1860377937555313
# Epoch 980 | Fold 4 | Test Loss 0.241328164935112
# Epoch 985 | Fold 4 | Train Loss 0.18197724223136902
# Epoch 985 | Fold 4 | Test Loss 0.24333953857421875
# Epoch 990 | Fold 4 | Train Loss 0.18158233165740967
# Epoch 990 | Fold 4 | Test Loss 0.2412172108888626
# Epoch 995 | Fold 4 | Train Loss 0.18232500553131104
# Epoch 995 | Fold 4 | Test Loss 0.24183714389801025
# Epoch 1000 | Fold 4 | Train Loss 0.18247105181217194
# Epoch 1000 | Fold 4 | Test Loss 0.2420347034931183
# Epoch 1005 | Fold 4 | Train Loss 0.18048642575740814
# Epoch 1005 | Fold 4 | Test Loss 0.24208427965641022
# Epoch 1010 | Fold 4 | Train Loss 0.18261943757534027
# Epoch 1010 | Fold 4 | Test Loss 0.24632979929447174
# Epoch 1015 | Fold 4 | Train Loss 0.18103660643100739
# Epoch 1015 | Fold 4 | Test Loss 0.2425505518913269
# Epoch 1020 | Fold 4 | Train Loss 0.181240051984787
# Epoch 1020 | Fold 4 | Test Loss 0.24063357710838318
# Epoch 1025 | Fold 4 | Train Loss 0.1797167807817459
# Epoch 1025 | Fold 4 | Test Loss 0.24039825797080994
# Epoch 1030 | Fold 4 | Train Loss 0.18069839477539062
# Epoch 1030 | Fold 4 | Test Loss 0.24105966091156006
# Epoch 1035 | Fold 4 | Train Loss 0.18199166655540466
# Epoch 1035 | Fold 4 | Test Loss 0.24166415631771088
# Epoch 1040 | Fold 4 | Train Loss 0.1795535534620285
# Epoch 1040 | Fold 4 | Test Loss 0.24073576927185059
# Epoch 1045 | Fold 4 | Train Loss 0.17962273955345154
# Epoch 1045 | Fold 4 | Test Loss 0.2489462047815323
# Epoch 1050 | Fold 4 | Train Loss 0.178073912858963
# Epoch 1050 | Fold 4 | Test Loss 0.2408781498670578
# Epoch 1055 | Fold 4 | Train Loss 0.1815241426229477
# Epoch 1055 | Fold 4 | Test Loss 0.2440483570098877
# Epoch 1060 | Fold 4 | Train Loss 0.17940843105316162
# Epoch 1060 | Fold 4 | Test Loss 0.2409590184688568
# Epoch 1065 | Fold 4 | Train Loss 0.1799020916223526
# Epoch 1065 | Fold 4 | Test Loss 0.24199289083480835
# Epoch 1070 | Fold 4 | Train Loss 0.1782388985157013
# Epoch 1190 | Fold 4 | Test Loss 0.23973135650157928
# Epoch 1195 | Fold 4 | Train Loss 0.17487818002700806
# Epoch 1195 | Fold 4 | Test Loss 0.24015843868255615
# Epoch 1200 | Fold 4 | Train Loss 0.17359785735607147
# Epoch 1200 | Fold 4 | Test Loss 0.23955653607845306
# Done for fold 4

# %%
n=0
fold = 4

plt.plot(figsize =(3, 2))

plt.title(f'Learning Curve Fold {fold}', fontweight ='bold')

plt.plot(range(0,epochs,5)[n:], loss_train_folds[fold, n:], 'o-', label = 'Train', color = 'blue')
plt.plot(range(0,epochs,5)[n:], loss_test_folds[fold, n:], 'o-', label = 'Test', color = 'darkorange')
plt.xlabel('Epochs', fontweight ='bold', fontsize = 12)
plt.ylabel('Loss', fontweight ='bold', fontsize = 12)
plt.legend()
plt.show()

# %%
e = 240
fold = 2

true_train = labels_train_folds[fold][:, e]
predicted_train = pred_train_folds[fold][:, e]
true_test = labels_test_folds[fold][:, e]
predicted_test = pred_test_folds[fold][:, e]


plt.plot(figsize =(6, 4))

plt.title(f'Predicted-Calculated Plot Fold {fold}, e = {e}', fontweight ='bold')

plt.scatter(true_train, predicted_train, color = 'blue', label = 'Train')
plt.scatter(true_test , predicted_test, color = 'darkorange', label = 'Test')
plt.xlabel("Calculated Energy (DFT) / eV", fontweight ='bold', fontsize = 12)
plt.ylabel("Predicted Energy / eV", fontweight ='bold', fontsize = 12)
plt.legend()

plt.plot( [2, 4],[2+.23, 4+.23], color = 'orangered', ls = ':', alpha = .2 )

plt.plot( [2, 4.5],[2, 4.5], color = 'orangered' )

plt.plot( [2+.23, 4+.23],[2, 4], color = 'orangered', ls = ':', alpha = .2 )

plt.text(2, 3.5, f'$R^2$: {r2_score(true_train,predicted_train):.2f} \n\
MAE: {mean_absolute_error(true_train, predicted_train):.2f} \n\
RMSE: {sqrt(mean_squared_error(true_train, predicted_train)):.2f}', color = 'b')

plt.text(4.2, 2.8, f'$R^2$: {r2_score(true_test, predicted_test):.2f} \n\
MAE: {mean_absolute_error(true_test, predicted_test):.2f} \n\
RMSE: {sqrt(mean_squared_error(true_test, predicted_test)):.2f}', color = '#e67e00')

plt.show()

# %%
e = 7
fold = 2

r_train = labels_train_folds[e,:,fold]
p_train = pred_train_folds[e,:,fold]
grad = pred_train_folds[e,:,fold] - labels_train_folds[e,:,fold]
files_train = file_train_folds[e,:,fold]

train_trace = go.Scatter(x=r_train,
                         y=p_train,
                         mode='markers',
                         name= 'Train set',
                         opacity=.7, 
                         hovertemplate = 
                         'Predicted: %{y:.2f}'+
                        '<br>Calculated: %{x:.2f}<br>'+
                        '%{text}',
                        text = ['File: {}.vasp'.format(int(i)) for i in files_train],
                         marker=dict(symbol='circle',
                                     size=5,
                                     color='black')
                            )


r_test = labels_test_folds[e,:,fold]
p_test = pred_test_folds[e,:,fold]
grad = pred_test_folds[e,:,fold] - labels_test_folds[e,:,fold]
files_test = file_test_folds[e,:,fold]

test_trace = go.Scatter(x=r_test,
                         y=p_test,
                         mode='markers',
                         name= 'Test set',
                         hovertemplate = 
                         '<i>Predicted</i>: %{y:.2f}'+
                        '<br>Calculated: %{x:.2f}<br>'+
                        '%{text}',
                        text = ['File: {}.vasp'.format(int(i)) for i in files_test],

                         marker=dict(symbol='circle',
                                     size=5,
                                     color=-abs(grad),
                                     colorscale='Hot')
                            )


trace_edges= go.Scatter(x=[min(labels_train_folds[e,:,fold]), max(labels_train_folds[e,:,fold])],
                        y=[min(labels_train_folds[e,:,fold]), max(labels_train_folds[e,:,fold])],
                        text='Identity line',
                        mode='lines',
                        name='Identity',
                        line=dict(color='black', width=1,dash='dash'),
                        hoverinfo='none')

traces = [train_trace, test_trace, trace_edges]

fig = go.Figure(data=traces)

fig.update_xaxes(title_text="Calculated DFT Energy / eV")
fig.update_yaxes(title_text="Predicted Energy / eV")

fig.update_layout(autosize=False,
    width=900,
    height=600, 
    template = 'none')

fig.show()

# %%
r2_global_test = []
for e in range(len(range(0,epochs,5))):
    r2_test = [r2_score(labels_test_folds[f][:, e], pred_test_folds[f][:, e])
                  for f in range(len(train_idx))]
    r2_global_test.append(r2_test)
    
mae_global_test = []
for e in range(len(range(0,epochs,5))):
    mae_test = [mean_absolute_error(labels_test_folds[f][:, e], pred_test_folds[f][:, e])
                  for f in range(len(train_idx))]
    mae_global_test.append(mae_test)

rmse_global_test = []
for e in range(len(range(0,epochs,5))):
    rmse_test = [sqrt(mean_squared_error(labels_test_folds[f][:, e], pred_test_folds[f][:, e]))
                  for f in range(len(train_idx))]
    rmse_global_test.append(rmse_test)

# %%
mean_r2_test = []
std_r2_test = []

mean_mae_test = []
std_mae_test = []

mean_rmse_test = []
std_rmse_test = []

for i in range(len(range(0,epochs,5))):

    mean_r2_test.append(np.mean(r2_global_test[i]))
    std_r2_test.append(np.std(r2_global_test[i]))

    mean_mae_test.append(np.mean(mae_global_test[i]))
    std_mae_test.append(np.std(mae_global_test[i]))

    mean_rmse_test.append(np.mean(rmse_global_test[i]))
    std_rmse_test.append(np.std(rmse_global_test[i]))

# %%
print(f'e value for best R2: {mean_r2_test.index(max(mean_r2_test))}')
print(f'e value for best MAE: {mean_mae_test.index(min(mean_mae_test))}')
print(f'e value for best RMSE: {mean_rmse_test.index(min(mean_rmse_test))}')
# Out:
# e value for best R2: 227
# e value for best MAE: 224
# e value for best RMSE: 227

# %%
all = [sum(x) for x in zip(mean_mae_test, mean_rmse_test)]
all_std = [sum(x) for x in zip(std_mae_test, std_rmse_test)]
all_ms = [x*y for x,y in zip(all, all_std)]
print(f'e value for best General with std: {all_ms.index(min(all_ms))}')
print(f'e value for best General no std: {all.index(min(all))}')
# Out:
# e value for best General with std: 123
# e value for best General no std: 240

# %%
e = 240
plt.plot(figsize =(6, 4))

plt.title(f'Metrics for all folds, e = {e}', fontweight ='bold')

plt.plot(range(len(train_idx)), r2_global_test[e], 'o-', label = '$R^2$', color = 'navy')
plt.plot(range(len(train_idx)), mae_global_test[e], 'v-', label = '$MAE$', color = 'darkorange')
plt.plot(range(len(train_idx)), rmse_global_test[e], 's-', label = 'RMSE', color = 'darkgreen')
plt.xticks(range(len(train_idx)), range(5))

plt.xlabel('Fold', fontweight ='bold', fontsize = 15)
plt.ylabel('Metric value', fontweight ='bold', fontsize = 15)
plt.legend()
plt.show()

# %%
Metrics = ['$R^2$', '$MAE$', '$RMSE$']
x_pos = np.arange(len(Metrics))
CTEs = [mean_r2_test[e], mean_mae_test[e], mean_rmse_test[e]]
error = [std_r2_test[e], std_mae_test[e], std_rmse_test[e]]
CTEs = [round(metric, 3) for metric in CTEs]

# %%
fig, ax = plt.subplots(figsize =(6, 4))
bars = ax.bar(x_pos, CTEs, yerr=error, align='center', color = 'navy', alpha=.5, ecolor='black', capsize=10)
ax.set_ylabel('Value', fontweight ='bold', fontsize = 12)
ax.bar_label(bars)
ax.set_xticks(x_pos)
ax.set_xticklabels(Metrics, fontweight ='bold' ,fontsize = 10)
ax.yaxis.grid(False)

plt.tight_layout()
plt.show()
print(error)
# Out:
# [0.02569846200868378, 0.014725499681164387, 0.02025437893793221]

# %%
# set width of bar
barWidth = 0.25
fig = plt.subplots(figsize =(6, 4))

plt.title(f'Average metrics for all folds', fontweight ='bold')

# set height of bar
R2 = mean_r2_test
MAE = mean_mae_test
RMSE = mean_rmse_test
 
# Set position of bar on X axis
br1 = np.arange(len(R2))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
 
# Make the plot
plt.bar(br1, R2, color ='navy', width = barWidth,
        edgecolor ='white', label ='$R^2$')
plt.bar(br2, MAE, color ='darkorange', width = barWidth,
        edgecolor ='white', label ='$MAE$')
plt.bar(br3, RMSE, color ='darkgreen', width = barWidth,
        edgecolor ='white', label ='$RMSE$')
 
# Adding Xticks
plt.xlabel('e value', fontweight ='bold', fontsize = 15)
plt.ylabel('Metric value', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(R2))],
        [i for i in range(len(R2))])
 
plt.legend()
plt.show()

# %%
best_r2 = r2_global_test[e]
best_mae = mae_global_test[e]
best_rmse = rmse_global_test[e]

# %%
df = pd.DataFrame(list(zip(best_r2, best_mae, best_rmse)), columns = ['R2', 'MAE', 'RMSE'])
max = pd.DataFrame(np.transpose(np.array(df.max()))).T
max.columns = df.columns
max = max.rename(index={0:'Max'})
min = pd.DataFrame(np.transpose(np.array(df.min()))).T
min.columns = df.columns
min = min.rename(index={0:'Min'})
mean = pd.DataFrame(np.transpose(np.array(df.mean()))).T
mean.columns = df.columns
mean = mean.rename(index={0:'Mean'})
std = pd.DataFrame(np.transpose(np.array(df.std()))).T
std.columns = df.columns
std = std.rename(index={0:'Std'})
df = pd.concat([df,max,min,mean,std], axis = 0)
df.index.name = 'fold'
df
# Out:
#             R2       MAE      RMSE
# fold
# 0     0.797409  0.184272  0.231781
# 1     0.825882  0.162187  0.225093
# 2     0.855002  0.146768  0.189270
# 3     0.824536  0.161909  0.219042
# 4     0.777216  0.192030  0.253258
# Max   0.855002  0.192030  0.253258
# Min   0.777216  0.146768  0.189270
# Mean  0.816009  0.169433  0.223689
# Std   0.029755  0.018396  0.023173
